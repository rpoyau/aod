# %% [markdown]
# # Alpha↔Omega Dynamics (AOD): Companion Notebook — Supplement C Solar (C2–C3)
#
# **Author:** P. Reginald
# **Protocol:** Axiomatic Fundamentalism Calculus (AFC)
# **Package role:** Supplement C grouped companion notebook
# **Notebook routing:** Grouped solar notebook layer; cited row first; converted witnesses attach only after the cited row.
# **Source of truth:** `supplement-c/examples/02_c2_solar_lensing_native_window.tex`, `supplement-c/examples/03_c3_solar_redshift_native_window.tex`
# **Repo provenance:** `supplement-c/notebooks/solar/c2_c3_solar_radiation_worked.ipynb`

# %% [markdown]
# ## Methodology
#
# Every section follows this structure:
# - Question
# - Readout
# - Operator Chain
# - Output Row
# - Temporal Conversion Block (only when needed)
# - Converted Witness Table (only when needed)
# - Figure Witness
# - Hook / Evidence
#
# **Temporal Conversion Block**
# Temporal conversion is a normal chain-rule expansion on the cited row.
# When conversion is required, convert only from cited bip/biz quantities into derived temporal SI forms.
# Duration converts to **seconds**.
# Rate converts to **hertz**.
# Effective speed is reported only as
# \[
# \beta=\frac{v}{c},\qquad c=1,\qquad 0\le\beta\le1.
# \]

# %% [markdown]
# # C2/C3 solar radiation worked notebook
# Compact render-layer anchors for the solar duon export windows.

# %%
GM_sun = 1.32712440041279419e20  # m^3 s^-2, JPL SSD astrodynamic parameters
c = 299_792_458.0                # m s^-1, JPL SSD / CODATA
R_sun = 695_700_000.0            # m, NASA solar radius rendering anchor
arcsec_per_rad = 206264.80624709636
delta_graze = 4*GM_sun/(c*c*R_sun)
delta_arcsec = delta_graze*arcsec_per_rad
z_sun = GM_sun/(c*c*R_sun)
delta_graze, delta_arcsec, z_sun
# Out:
# (8.490010283222196e-06, 1.751190326104682, 2.122502570805549e-06)

# %% [markdown]
# ## Converted witness tables
# The tables below record the rendered lensing and redshift witnesses against the cited reference anchors.

# %%
import pandas as pd
df_c2_cmp = pd.DataFrame([{'subledger':'Solar export slice','calculated_arcsec':1.7512432813682448,'reference_arcsec':1.75,'abs_error_arcsec':0.0012432813682448,'rel_error_percent':0.07104464961399}])
df_c3_cmp = pd.DataFrame([{'subledger':'Source--receiver transfer','calculated':2.122566754396204e-6,'reference':2.12e-6,'abs_error':2.566754396204e-9,'rel_error_percent':0.12107332057566}])
display(df_c2_cmp)
display(df_c3_cmp)

# %%
print("ALL AOD NATIVE TESTS PASSED ✓")
