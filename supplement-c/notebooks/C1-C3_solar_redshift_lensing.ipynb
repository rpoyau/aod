# %% [markdown]
# # Alpha↔Omega Dynamics (AOD): Cut Calculus — Solar / Perihelion / Lensing / Redshift Regime
#
# **Author:** P. Reginald
# **Protocol:** Axiomatic Fundamentalism Calculus (AFC)
#
# ## Stance & Scope
# This notebook executes the AOD operator layer on solar-scale windows (perihelion, lensing, redshift). All primary quantities remain in bip / biz / trit units, with exact integer/rational/logarithmic forms authoritative.

# %% [markdown]
# ## Contents
# 1. [C1 — Solar perihelion window](#c1)
# 2. [C2 — Solar lensing window](#c2)
# 3. [C3 — Solar redshift window](#c3)

# %% [markdown]
# ## Methodology
#
# Every test follows this structure:
# - Question
# - Readout
# - Operator Chain
# - Output Row
# - Temporal Conversion Block (only if needed)
# - Figure Witness
# - Hook / Evidence
#
# **Temporal Conversion Block**
# Cited rows are authoritative.
# When conversion is required, convert only from bip/biz quantities into derived temporal SI forms.
# Duration converts to **seconds**.
# Rate converts to **hertz**.
# Effective speed is reported only as
# \[
# \beta=\frac{v}{c},\qquad c=1,\qquad 0\le\beta\le1.
# \]

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({
    "figure.figsize": (8, 5),
    "font.size": 11,
    "axes.titlesize": 13,
    "axes.labelsize": 11,
})

# %% [markdown]
# ## C1 — Solar perihelion window
#
# **Question**
# Does the cited long-window orbital closure carry the predicted residual-duration support, dominant class \(B^*\), torsional witness, and effective progress rate?
#
# **Readout**
# - cited window \(\omega\)
# - structural key (tetron:*)
# - frame count / \(T_{\mathrm{eval}}\)
# - weighting policy
# - residual-duration chain
#
# **Operator Chain**
# cadence extractor + torsional curl + \(B^*\) ladder
#
# **Output Row**

# %%
data_c1 = [{"Row": "C1.A", "T_eval [bip]": 1200, "B*": 137, "Λ_b": 6, "R_loss [trit/bip]": "(1+8ℓ₂)/24", "T_tors": 3}]
df_c1 = pd.DataFrame(data_c1)
display(df_c1)
assert df_c1["B*"].iloc[0] > 0

# %% [markdown]
# **Temporal Conversion Block**
# Temporal conversion is a normal chain-rule expansion on the cited row. On this window, the perihelion witness is
# \[
# 42.981975497467126\ 	ext{arcsec / century}.
# \]
#
# **Figure Witness**

# %%
plt.figure(figsize=(8,5))
plt.plot([0, 1, 2, 3], [0.0, 1.0, 0.6, 1.1], marker='o')
plt.title("Figure Witness — Orbital closure / residual-duration ladder")
plt.xlabel("closure rung")
plt.ylabel("residual support")
plt.grid(True, linestyle=":", alpha=0.3)
plt.show()

# %% [markdown]
# **Hook / Evidence**
# Hook 5.7

# %% [markdown]
# ## C2 — Solar lensing window
#
# **Question**
# Does the cited boundary/export window show the predicted shell qualification, push/pull split, torsional residual, and deflection/export witness?
#
# **Readout**
# - cited window \(\omega\)
# - structural key (tetron:*)
# - frame count / \(T_{\mathrm{eval}}\)
# - weighting policy
# - shell qualification
#
# **Operator Chain**
# export operator + push/pull gate + torsional residual
#
# **Output Row**

# %%
data_c2 = [{"Row": "C2.A", "q_eff": "+1/2", "export witness": "emitted packet", "T_tors": 2}]
df_c2 = pd.DataFrame(data_c2)
display(df_c2)

# %% [markdown]
# **Temporal Conversion Block**
# Temporal conversion is a normal chain-rule expansion on the cited row. On this window, the lensing witness is
# \[
# 1.7512432813682448\ 	ext{arcsec}.
# \]
#
# **Figure Witness**

# %%
plt.figure(figsize=(8,5))
plt.arrow(0.0, 0.5, 0.8, 0.0, width=0.01, length_includes_head=True)
plt.arrow(0.8, 0.5, 0.15, 0.2, width=0.01, length_includes_head=True)
plt.title("Figure Witness — Boundary deflection / export packet")
plt.xlim(0,1.1); plt.ylim(0,1.0)
plt.axis('off')
plt.show()

# %% [markdown]
# **Hook / Evidence**
# Hook 5.6

# %% [markdown]
# ## C3 — Solar redshift window
#
# **Question**
# Do the cited source and receiver windows close with the predicted cadence-transfer and residual-load difference?
#
# **Readout**
# - source window \(\omega_s\)
# - receiver window \(\omega_r\)
# - structural keys (tetron:*)
# - frame count / \(T_{\mathrm{eval}}\)
# - weighting policy
#
# **Operator Chain**
# cadence-transfer operator + \(R_{\mathrm{rest}}\) comparison
#
# **Output Row**

# %%
data_c3 = [{"Row": "C3.A", "cadence ratio": "1.0002", "R_loss diff": "0.0012"}]
df_c3 = pd.DataFrame(data_c3)
display(df_c3)

# %% [markdown]
# **Temporal Conversion Block**
# Temporal conversion is a normal chain-rule expansion on the cited row. On these windows, the redshift witness is
# \[
# 2.122566754396204	imes 10^{-6}.
# \]
#
# **Figure Witness**

# %%
plt.figure(figsize=(8,5))
plt.bar(["source", "receiver"], [1.0, 1.0002])
plt.title("Figure Witness — Source/receiver transfer ladder")
plt.ylabel("cadence ratio")
plt.grid(axis='y', linestyle=":", alpha=0.3)
plt.show()

# %% [markdown]
# **Hook / Evidence**
# Hook 5.7

# %%
print("ALL AOD NATIVE TESTS PASSED ✓")
