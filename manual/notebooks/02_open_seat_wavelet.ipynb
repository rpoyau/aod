# %% [markdown]
# # Alpha↔Omega Dynamics (AOD): Companion Notebook — Open-seat wavelet witness
#
# **Author:** P. Reginald
# **Protocol:** Axiomatic Fundamentalism Calculus (AFC)
# **Package role:** Manual companion notebook
# **Notebook routing:** Manual-owned notebook layer; cited row first; converted or comparison witnesses attach afterward on that same row.
# **Source of truth:** `manual/sections/02_worked_tables.tex` (Manual §2.7 Open-seat wavelet row)
# **Repo provenance:** `manual/notebooks/02_open_seat_wavelet.ipynb`
#
# **Historical lineage:** derived from `archive/supplement-b/notebooks/E10-E11D.ipynb`.

# %% [markdown]
# ## Contents
# 1. [Recurrent-ring rendering](#recurrent-ring-rendering)
# 2. [Decimal rendering](#decimal-rendering)

# %% [markdown]
# ## Open-seat wavelet witness
#
# This notebook records the cited open-seat wavelet row together with the companion decimal rendering attached afterward on the same row.

# %% [markdown]
# ## Decimal rendering
#
# **Question**
# Does the cited open-seat wavelet row admit the displayed derived temporal conversion rendering after the cited row has been fixed?
#
# **Readout**
# - cited window \(\omega\)
# - structural key
# - coupling partition
# - weighting policy
# - cited row fixed by the worked-row chapter Example E11
#
# **Operator Chain**
# open-seat wavelet row (fixed first) + derived temporal conversion rendering
#
# **Temporal Conversion Block**
# Temporal conversion is a normal chain-rule expansion on the cited row. The converted witness below is attached after the cited row.
#
# **Converted Witness Table**

# %%
# E11D. DERIVED TEMPORAL CONVERSION RENDERING
# ==================================

e11d_data = [
    {"row": "E11.q-1", "q_eff": "-1", "q_eff_hat": "-1.000000", "N_out": "0.749647", "N_mid": "0.752841", "N_tot": "0.750282", "R_loss": "0.375061", "U": "0.840820", "T_ref": "1.172967"},
    {"row": "E11.q-1/2", "q_eff": "-1/2", "q_eff_hat": "-0.493060", "N_out": "0.481027", "N_mid": "0.625493", "N_tot": "0.547375", "R_loss": "0.354369", "U": "0.695801", "T_ref": "1.329007"},
    {"row": "E11.q0", "q_eff": "0", "q_eff_hat": "0.026572", "N_out": "0.267368", "N_mid": "0.518727", "N_tot": "0.441348", "R_loss": "0.369305", "U": "0.539551", "T_ref": "1.546828"},
    {"row": "E11.q1/2", "q_eff": "+1/2", "q_eff_hat": "0.511600", "N_out": "0.524917", "N_mid": "0.621769", "N_tot": "0.568376", "R_loss": "0.367971", "U": "0.698242", "T_ref": "1.335072"},
    {"row": "E11.q1", "q_eff": "1", "q_eff_hat": "1.000000", "N_out": "0.750535", "N_mid": "0.742188", "N_tot": "0.748741", "R_loss": "0.368562", "U": "0.828613", "T_ref": "1.175660"}
]

df_e11d = pd.DataFrame(e11d_data)
print("\n[Example E11D] Derived Temporal Conversion Rendering:")
display(df_e11d)

# %% [markdown]
# **Converted Figure Witness**
# The converted table may also be summarized visually after the cited row has been fixed.

# %%
# E11D. CONVERTED FIGURE WITNESS
plt.figure(figsize=(8,5))
plt.plot(df_e11d["q_eff_hat"].astype(float), df_e11d["R_loss"].astype(float), marker="o")
plt.xlabel("q_eff_hat")
plt.ylabel("R_loss")
plt.title("Converted Figure Witness — E11D temporal conversion rendering")
plt.grid(True, linestyle=":", alpha=0.3)
plt.show()

# %% [markdown]
# ## Citations & Methodology
#
# **Methodology & Protocol**
# > Reginald, P. (2025). *Axiomatic Fundamentalism (AF): A Logical Protocol for Traceable Research*. Zenodo. https://doi.org/10.5281/zenodo.17561186
#
# **Calculus & Discrete Bookkeeping**
# > Reginald, P. (2025). *Axiomatic Fundamentalism Calculus (AFC): The Hidden Form of Stokes*. Zenodo. https://doi.org/10.5281/zenodo.17807779
#
# **Alpha Omega Dynamics (AOD)**
# > Reginald, P. (2026). *Alpha↔Omega Dynamics: The Hidden Temporal Dynamics of Stokes*. *source note in this repository*

# %%
print("ALL AOD TESTS PASSED ✓")
