# %% [markdown]
# # Alpha↔Omega Dynamics (AOD): Companion Notebook — Solar system: Mercury perihelion
#
# **Author:** P. Reginald
# **Protocol:** Axiomatic Fundamentalism Calculus (AFC)
# **Package role:** Manual companion notebook
# **Notebook routing:** Manual-owned notebook layer; declared row first; converted or comparison witnesses attach afterward on that same row.
# **Source of truth:** `manual/sections/04a_solar_system.tex` (Manual §4.1.1 Anomalous perihelion precession of Mercury)
# **Repo provenance:** `manual/notebooks/04a_solar_system_mercury_perihelion.ipynb`
#
# **Provenance:** manual-local notebook row; source section and companion data are declared in this notebook header.

# %% [markdown]
# ## Method
#
# This notebook fixes the declared row first and attaches converted or comparison witnesses afterward where needed. The public section remains the source of truth; the notebook is a runnable companion.

# %% [markdown]
# # Mercury perihelion support note
#
# For C1, $B^*$ is not computed from $R_{\mathrm{loss}}$. On the declared window, $B^*$ is read from the return-duration burden chain
#
# $$b(\kappa) \to H_B \to B^* \to \Lambda_b,$$
#
# whereas $R_{\mathrm{loss}}$ is read from the loss/tension channel. Both are reported from the same declared row.
#
# For the same declared row, the source monon beat is not fixed by hand. It is derived by the local quarter-cycle causality-speed extractor
#
# $$\chi_4(O_i;\omega)=\lambda_i-\Lambda_b(\omega)-\lfloor 24R_{\mathrm{loss}}(\omega)\rfloor,$$
#
# with the rendered source beat read from the resulting quarter-count on the 100-year horizon.

# %% [markdown]
# # C1 Solar 100-year worked anchors
#
# This notebook mirrors the compact calculation spine used in the modular C1 section:
#
# - input dictionary anchors
# - body-to-rate bridge $m \to m_z$
# - quarter-level count $\lambda = \log_3(m_z)/4$
# - 100-year orbit-count renderings
# - shell/ring figure artifacts
# - derived source monon beat / causality-speed witness

# %%
import math
import pandas as pd

c = 299792458.0
h = 6.62607015e-34

def m_z(m):
    return m*c*c/h

def lam(m):
    return math.log(m_z(m), 3)/4.0

masses = {
    'Sun': 1.98892e30,
    'Mercury': 3.3011e23,
    'Venus': 4.8675e24,
    'Earth': 5.97219e24,
    'Moon': 7.34767e22,
    'Mars': 6.4171e23,
    'Jupiter': 1.89819e27,
    'Saturn': 5.6834e26,
    'Uranus': 8.6810e25,
    'Neptune': 1.02413e26,
}

periods = {
    'Mercury': 0.2408467,
    'Venus': 0.61519726,
    'Earth': 1.0000174,
    'Mars': 1.8808476,
    'Jupiter': 11.862615,
    'Saturn': 29.447498,
    'Uranus': 84.016846,
    'Neptune': 164.79132,
}


ell2 = math.log(3/2, 3)
Rloss = (1 + 8*ell2)/24
Lambda_b = 6
loss_ticks = math.floor(24*Rloss)
chi4_source = lam(masses['Sun']) - Lambda_b - loss_ticks
source_cycles_100y = 100.0/chi4_source

rows = []
for body, m in masses.items():
    rows.append({
        'body': body,
        'mass_kg': m,
        'm_z_s^-1': m_z(m),
        'lambda_quarter': lam(m),
        'cycles_100y': (100.0/periods[body]) if body in periods else None,
        'source_monon_beat_y': chi4_source if body == 'Sun' else None,
        'source_monon_cycles_100y': source_cycles_100y if body == 'Sun' else None,
    })

df = pd.DataFrame(rows)
df
# Out:
#       body       mass_kg  ...  source_monon_beat_y  source_monon_cycles_100y
# 0      Sun  1.988920e+30  ...              33.1439                  3.017146
# 1  Mercury  3.301100e+23  ...                  NaN                       NaN
# 2    Venus  4.867500e+24  ...                  NaN                       NaN
# 3    Earth  5.972190e+24  ...                  NaN                       NaN
# 4     Moon  7.347670e+22  ...                  NaN                       NaN
# 5     Mars  6.417100e+23  ...                  NaN                       NaN
# 6  Jupiter  1.898190e+27  ...                  NaN                       NaN
# 7   Saturn  5.683400e+26  ...                  NaN                       NaN
# 8   Uranus  8.681000e+25  ...                  NaN                       NaN
# 9  Neptune  1.024130e+26  ...                  NaN                       NaN
#
# [10 rows x 7 columns]

# %% [markdown]
# The public manual uses **rounded renderings** only. The full floating-point values stay here in the notebook, not in the PDF section.

# %%
df[['body','m_z_s^-1','lambda_quarter','cycles_100y','source_monon_beat_y','source_monon_cycles_100y']].round({'m_z_s^-1':3,'lambda_quarter':3,'cycles_100y':3,'source_monon_beat_y':3,'source_monon_cycles_100y':3})
# Out:
#       body      m_z_s^-1  ...  source_monon_beat_y  source_monon_cycles_100y
# 0      Sun  2.697756e+80  ...               33.144                     3.017
# 1  Mercury  4.477587e+73  ...                  NaN                       NaN
# 2    Venus  6.602240e+74  ...                  NaN                       NaN
# 3    Earth  8.100634e+74  ...                  NaN                       NaN
# 4     Moon  9.966324e+72  ...                  NaN                       NaN
# 5     Mars  8.704106e+73  ...                  NaN                       NaN
# 6  Jupiter  2.574691e+77  ...                  NaN                       NaN
# 7   Saturn  7.708921e+76  ...                  NaN                       NaN
# 8   Uranus  1.177484e+76  ...                  NaN                       NaN
# 9  Neptune  1.389122e+76  ...                  NaN                       NaN
#
# [10 rows x 6 columns]

# %% [markdown]
# ## Converted witness table
# The table below records the rendered perihelion witness against the declared reference anchor.

# %%
import pandas as pd
df_c1_cmp = pd.DataFrame([{'subrow':'Mercury perihelion slice','calculated_arcsec_per_century':42.981975497467126,'reference_arcsec_per_century':42.98,'abs_error_arcsec_per_century':0.001975497467126,'rel_error_percent':0.00459631797843}])
display(df_c1_cmp)

# %%
print("ALL AOD TESTS PASSED ✓")
