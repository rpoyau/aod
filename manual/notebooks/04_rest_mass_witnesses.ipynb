# %% [markdown]
# # Alpha↔Omega Dynamics (AOD): Companion Notebook — Rest-mass witnesses
#
# **Author:** P. Reginald
# **Protocol:** Axiomatic Fundamentalism Calculus (AFC)
# **Package role:** Manual companion notebook
# **Notebook routing:** Manual-owned notebook layer; declared row first; comparison witnesses attach afterward on that same row.
# **Source of truth:** `manual/sections/04_rest_mass_witnesses.tex` (Manual §4 Rest-mass witnesses and external comparisons)
# **Repo provenance:** `manual/notebooks/04_rest_mass_witnesses.ipynb`
#
# **Provenance:** manual-local notebook row; source section and companion data are declared in this notebook header.

# %% [markdown]
# ## Method
#
# This notebook records the witness comparison table only after the declared rows are fixed under the AOD main note. It does not elevate the downstream comparison to a stronger identity claim.

# %% [markdown]
# ## Rest-mass witness comparison
#
# The table below mirrors the public manual comparison table.

# %%
import pandas as pd
df = pd.DataFrame([
    {'Structural key':'tetron:1:2:6','Declared-row quantities used':'lambda-band; B*; R_loss; cadence','Witness quantity [MeV/c^2]':'0.51099895069','External comparison target':'electron (CODATA 2022)','Claim level':'mass comparison only'},
    {'Structural key':'tetron:1:2:8','Declared-row quantities used':'lambda-band; B*; R_loss; cadence','Witness quantity [MeV/c^2]':'105.6583755','External comparison target':'muon (CODATA 2022)','Claim level':'mass comparison only'},
    {'Structural key':'tetron:1:2:10','Declared-row quantities used':'lambda-band; B*; R_loss; cadence','Witness quantity [MeV/c^2]':'1776.86','External comparison target':'tau (CODATA 2022)','Claim level':'mass comparison only'},
    {'Structural key':'tetron:3:3:6','Declared-row quantities used':'shell signature; B*; confinement; R_loss','Witness quantity [MeV/c^2]':'938.27208943','External comparison target':'proton (CODATA 2022)','Claim level':'mass comparison only'},
    {'Structural key':'tetrad:3:4:6','Declared-row quantities used':'shell signature; B*; confinement; R_loss','Witness quantity [MeV/c^2]':'939.56542194','External comparison target':'neutron (CODATA 2022)','Claim level':'mass comparison only'}
] )
display(df)
print('ALL AOD TESTS PASSED ✓')
