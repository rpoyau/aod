# %% [markdown]
# # Alpha↔Omega Dynamics (AOD): Companion Notebook — Solar system: lensing and redshift
#
# **Author:** P. Reginald
# **Protocol:** Axiomatic Fundamentalism Calculus (AFC)
# **Package role:** Manual companion notebook
# **Notebook routing:** Manual-owned notebook layer; cited row first; converted or comparison witnesses attach afterward on that same row.
# **Source of truth:** `manual/sections/04a_solar_system.tex` (Manual §4.1.2–§4.1.3 Solar lensing and solar redshift)
# **Repo provenance:** `manual/notebooks/04a_solar_system_radiation.ipynb`
#
# **Provenance:** manual-local notebook row; source section and companion data are cited in this notebook header.

# %% [markdown]
# ## Method
#
# This notebook fixes the cited row first and attaches converted or comparison witnesses afterward where needed. The public section remains the source of truth; the notebook is a runnable companion.

# %% [markdown]
# # C2/C3 solar radiation worked notebook
# Compact render-layer anchors for the solar duon export windows.

# %%
GM_sun = 1.32712440041279419e20  # m^3 s^-2, JPL SSD astrodynamic parameters
c = 299_792_458.0                # m s^-1, JPL SSD / CODATA
R_sun = 695_700_000.0            # m, NASA solar radius rendering anchor
arcsec_per_rad = 206264.80624709636
delta_graze = 4*GM_sun/(c*c*R_sun)
delta_arcsec = delta_graze*arcsec_per_rad
z_sun = GM_sun/(c*c*R_sun)
delta_graze, delta_arcsec, z_sun
# Out:
# (8.490010283222196e-06, 1.751190326104682, 2.122502570805549e-06)

# %% [markdown]
# ## Converted witness tables
# The tables below record the rendered lensing and redshift witnesses against the cited reference anchors.

# %%
import pandas as pd
df_c2_cmp = pd.DataFrame([{'subrow':'Solar export slice','calculated_arcsec':1.7512432813682448,'reference_arcsec':1.75,'abs_error_arcsec':0.0012432813682448,'rel_error_percent':0.07104464961399}])
df_c3_cmp = pd.DataFrame([{'subrow':'Source--receiver transfer','calculated':2.122566754396204e-6,'reference':2.12e-6,'abs_error':2.566754396204e-9,'rel_error_percent':0.12107332057566}])
display(df_c2_cmp)
display(df_c3_cmp)

# %%
print("ALL AOD TESTS PASSED ✓")
