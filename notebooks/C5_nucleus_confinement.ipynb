# %% [markdown]
# # Alpha↔Omega Dynamics (AOD): Native Cut Calculus — Nucleus Confinement Regime
#
# **Author:** P. Reginald
# **Protocol:** Axiomatic Fundamentalism Calculus (AFC)
#
# ## Stance & Scope
# This notebook executes the native AOD operator layer on short-window confinement and neutron stability. All primary quantities remain native: trit/bip is primitive, biz is derived, and exact integer/rational/logarithmic forms are authoritative.

# %% [markdown]
# ## Contents
# 1. [C5 — Nucleus confinement / neutron stability](#c5)

# %% [markdown]
# ## Methodology
#
# Every test follows this structure:
# - Native Question
# - Native Readout
# - Native Operator Chain
# - Native Output Row
# - Temporal Conversion Block (only if needed)
# - Native Figure Witness
# - Hook / Evidence
#
# **Temporal Conversion Block**
# Native rows are authoritative.
# When conversion is required, convert only from native bip/biz quantities into derived temporal SI forms.
# Duration converts to **seconds**.
# Rate converts to **hertz**.
# Effective speed is reported only as
# \[
# \beta=\frac{v}{c},\qquad c=1,\qquad 0\le\beta\le1.
# \]

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({
    'figure.figsize': (8, 5),
    'font.size': 11,
    'axes.titlesize': 13,
    'axes.labelsize': 12,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'axes.grid': True,
    'grid.alpha': 0.3,
    'grid.linestyle': ':'
})

print('AOD Native Operator Environment Initialised.')

l2 = math.log(1.5, 3)

# %% [markdown]
# ## C5 — Nucleus confinement / neutron stability
#
# **Native Question**
# Does the cited short-window confinement class satisfy the shell-signature, proximity, and B*-dominance conditions required for persistence, or does it cross the transmutation threshold?
#
# **Native Readout**
# - cited window \(\omega\)
# - structural key
# - frame count / \(T_{\mathrm{eval}}\)
# - weighting policy
# - shell signature / native inputs as needed
#
# **Native Operator Chain**
# \(e_\alpha, e_\Omega, f \to b(\kappa) \to H_B \to B^* \to \Lambda_b \to\) confinement predicate \(+\) transmutation flag
#
# **Native Output Row**

# %%
data_c5 = [
    {
        "Row": "C5.A",
        "Native key": "tetron:3:3:6",
        "T_eval [bip]": 256,
        "Weighting policy": "uniform",
        "shell signature": "(lambda=3/2, 137, rho_2, V_4)",
        "B*": 137,
        "Lambda_b": 6,
        "proximity": "close",
        "confinement": "confined",
        "transmutation flag": 0,
        "R_rest [trit/bip]": "(1 + 8*l2)/24"
    },
    {
        "Row": "C5.B",
        "Native key": "tetron:3:3:6",
        "T_eval [bip]": 256,
        "Weighting policy": "uniform",
        "shell signature": "(lambda=3/2, 139, rho_3, V_4)",
        "B*": 139,
        "Lambda_b": 3,
        "proximity": "failed",
        "confinement": "unconfined",
        "transmutation flag": 1,
        "R_rest [trit/bip]": "(1 + 8*l2)/24"
    }
]

df_c5 = pd.DataFrame(data_c5)
display(df_c5)
assert len(df_c5) == 2
assert set(df_c5["transmutation flag"]) == {0, 1}
assert all(df_c5["B*"] > 0)

# %% [markdown]
# **Temporal Conversion Block**
# Temporal conversion is a normal chain-rule expansion on the cited native row. This test is retained in native units.

# %% [markdown]
# **Native Figure Witness**

# %%
labels = df_c5["Row"].tolist()
bstar = df_c5["B*"].tolist()
x = np.arange(len(labels))

fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(x, bstar)
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylabel("B*")
ax.set_title("Native Figure Witness — Confinement / shell-signature / transmutation")
ax.grid(axis="y", linestyle=":", alpha=0.3)
plt.show()

# %% [markdown]
# **Hook / Evidence**
# Hook 5.7

# %%
print("ALL AOD NATIVE TESTS PASSED ✓")
