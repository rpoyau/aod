# %% [markdown]
# # Alpha↔Omega Dynamics (AOD): Native Cut Calculus — Brownian Jitter Regime
#
# **Author:** P. Reginald
# **Protocol:** Axiomatic Fundamentalism Calculus (AFC)
#
# ## Stance & Scope
# This notebook executes the native AOD operator layer on recurrent jitter and Brownian bacteria motion. All primary quantities remain native: trit/bip is primitive, biz is derived, and exact integer/rational/logarithmic forms are authoritative.

# %% [markdown]
# ## Contents
# 1. [C7 — Brownian bacteria motion](#c7)

# %% [markdown]
# ## Methodology
#
# Every test follows this structure:
# - Native Question
# - Native Readout
# - Native Operator Chain
# - Native Output Row
# - Temporal Conversion Block (only if needed)
# - Native Figure Witness
# - Hook / Evidence
#
# **Temporal Conversion Block**
# Native rows are authoritative.
# When conversion is required, convert only from native bip/biz quantities into derived temporal SI forms.
# Duration converts to **seconds**.
# Rate converts to **hertz**.
# Effective speed is reported only as
# \[
# \beta=\frac{v}{c},\qquad c=1,\qquad 0\le\beta\le1.
# \]

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams.update({
    'figure.figsize': (8, 5),
    'font.size': 11,
    'axes.titlesize': 13,
    'axes.labelsize': 12,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'axes.grid': True,
    'grid.alpha': 0.3,
    'grid.linestyle': ':'
})

print('AOD Native Operator Environment Initialised.')

l2 = math.log(1.5, 3)

# %% [markdown]
# ## C7 — Brownian bacteria motion
#
# **Native Question**
# Does the cited recurrent jitter window show the predicted dwell distribution, residual-duration support, cadence-noise band, and service-burden profile?
#
# **Native Readout**
# - cited window \(\omega\)
# - structural key
# - frame count / \(T_{\mathrm{eval}}\)
# - weighting policy
# - shell signature / native inputs as needed
#
# **Native Operator Chain**
# \(e_\alpha, e_\Omega, f \to b(\kappa) \to H_B \to B^* \to \Lambda_b \to R_{\mathrm{rest}} \to\) cadence-noise witness \(+\) drift witness
#
# **Native Output Row**

# %%
data_c7 = [
    {
        "Row": "C7.A",
        "Native key": "tetron:2:2:4",
        "T_eval [bip]": 1024,
        "Weighting policy": "uniform",
        "B*": 2,
        "Lambda_b": 11,
        "R_rest [trit/bip]": "3/8",
        "dwell distribution": "recurrent jitter",
        "cadence-noise witness": "jitter band",
        "drift witness": "recurrent"
    }
]

df_c7 = pd.DataFrame(data_c7)
display(df_c7)
assert len(df_c7) == 1
assert df_c7["B*"].iloc[0] > 0

# %% [markdown]
# **Temporal Conversion Block**
# Temporal conversion is a normal chain-rule expansion on the cited native row. This test is retained in native units.

# %% [markdown]
# **Native Figure Witness**

# %%
bins = np.arange(1, 7)
counts = np.array([3, 6, 7, 5, 4, 2])

fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(bins, counts)
ax.set_xlabel("dwell class")
ax.set_ylabel("count")
ax.set_title("Native Figure Witness — Recurrent trajectory / jitter / dwell histogram")
ax.grid(axis="y", linestyle=":", alpha=0.3)
plt.show()

# %% [markdown]
# **Hook / Evidence**
# Hook 5.7

# %%
print("ALL AOD NATIVE TESTS PASSED ✓")
