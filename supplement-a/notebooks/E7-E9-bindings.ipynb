# %% [markdown]
# # Alpha↔Omega Dynamics (AOD): Companion Notebook — Supplement A (E7–E9)
#
# **Author:** P. Reginald
# **Protocol:** Axiomatic Fundamentalism Calculus (AFC)
# **Package role:** Supplement A companion notebook
# **Notebook routing:** Cited rows fixed first; any converted witness attaches only after the cited row.
# **Source of truth:** `supplement-a/examples/e07_field_property_schema.tex`, `supplement-a/examples/e08_short_window_confinement.tex`, `supplement-a/examples/e09_duon_duad_family.tex`
# **Repo provenance:** `supplement-a/notebooks/E7-E9-bindings.ipynb`

# %% [markdown]
# ## Methodology
#
# Every section follows this structure:
# - Question
# - Readout
# - Operator Chain
# - Output Row
# - Temporal Conversion Block (only when needed)
# - Converted Witness Table (only when needed)
# - Figure Witness
# - Hook / Evidence
#
# **Temporal Conversion Block**
# Temporal conversion is a normal chain-rule expansion on the cited row.
# When conversion is required, convert only from cited bip/biz quantities into derived temporal SI forms.
# Duration converts to **seconds**.
# Rate converts to **hertz**.
# Effective speed is reported only as
# \[
# \beta=\frac{v}{c},\qquad c=1,\qquad 0\le\beta\le1.
# \]

# %% [markdown]
# # E7--E9 field-family note
#
# This notebook records field-property, confinement, and family-row witnesses for Supplement A. Optional verification bindings and any decimal renderings are attached after the cited row and are routed through Supplement B.

# %% [markdown]
# # Alpha↔Omega Dynamics (AOD): Cut Calculus — Field-Property, Confinement & Family Regime
#
# **Author:** P. Reginald
# **Protocol:** Axiomatic Fundamentalism Calculus (AFC)
#
# ## Stance & Scope
# This notebook executes the AOD operator layer on the field-property schema, short-window confinement, and duon/duad family rows. All primary quantities remain in bip / biz / trit units, with exact integer/rational/logarithmic forms authoritative.

# %% [markdown]
# ## Contents
# 1. [E7 — Field-property schema](#e7)
# 2. [E8 — Short-window confinement](#e8)
# 3. [E9 — Duon / duad family](#e9)

# %% [markdown]
# ## Methodology
#
# Every test follows this structure:
# - Question
# - Readout
# - Operator Chain
# - Output Row
# - Temporal Conversion Block (only if needed)
# - Converted Witness Table (only if needed)
# - Figure Witness
# - Hook / Evidence
#
# **Temporal Conversion Block**
# Temporal conversion is a normal chain-rule expansion on the cited row.
# When conversion is required, convert only from cited bip/biz quantities into derived temporal SI forms.
# Duration converts to **seconds**.
# Rate converts to **hertz**.
# Effective speed is reported only as
# \[
# \beta=\frac{v}{c},\qquad c=1,\qquad 0\le\beta\le1.
# \]

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Constants
l2 = math.log(1.5, 3)  # log_3(3/2) in trits
B0 = 1.0               # 1 bip (burden reference)

print("AOD Operator Environment Initialised.")

# %% [markdown]
# ## 2. Example E7: Field-Property Schema Row
#
# **Setup:** One shell-qualified AO field instance reported on a fixed window contract. The schema row remains strictly in the bip / biz / trit gauge: `trit/bip` is primitive and `biz` is derived on the same cited ledger.

# %%
# E7. FIELD-PROPERTY SCHEMA ROW
# =============================

# Define the mathematical representations as strings for the report
r_rest_trit = f"(1 + 8*l_2) / 24"
r_rest_biz = f"(3^((1 + 8*l_2)/24) - 1) * 137^(-6)"

e7_data = [
    {"Field property": "AO field key", "Reported value": "O-tetrad:3:4:6"},
    {"Field property": "TTL", "Reported value": "24 bip"},
    {"Field property": "Cadence spectrum", "Reported value": "{1/4, 3/8, 5/12} [cyc/bip]"},
    {"Field property": "B* / Lambda_b", "Reported value": "137 / 6"},
    {"Field property": "R_loss", "Reported value": f"{r_rest_trit} [trit/bip]"},
    {"Field property": "R^(biz)", "Reported value": f"{r_rest_biz} [biz]"},
    {"Field property": "q_eff", "Reported value": "+1/2"},
    {"Field property": "T_tors", "Reported value": "3"}
]

df_e7 = pd.DataFrame(e7_data)
print("\n[Example E7] Field-Property Schema Row:")
display(df_e7)

# %% [markdown]
# ### Visual witness: shell signature and field-property row
#
# This plot summarizes the same field-property row through its cadence spectrum and loss channel on the cited shell-qualified window.

# %%
# E7 VISUAL: SHELL SIGNATURE / FIELD ROW
fig, ax = plt.subplots(1,2, figsize=(10,4))
ax[0].bar(['1/4','3/8','5/12'], [1/4,3/8,5/12])
ax[0].set_title('Cadence spectrum')
ax[0].set_ylabel('cycles/bip')
ax[1].bar(['R_loss','R^(biz)'], [float((1 + 8*l2)/24), 0.0])
ax[1].set_title('Loss channels')
ax[1].set_ylabel('value')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Examples E8 & E9: Confinement and Family Rows
#
# **Example E8 Setup:** A cited short shell-qualified tetron window with declared proximity policy. The same cited short window must resolve shell signature, dominant rung, proximity status, confinement witness, and transmutation flag on one family-conditioned ledger.
#
# **Example E9 Setup:** A cited two-seat family window with declared exposure, push/pull sign convention, export witness, and cadence extractor.

# %%
# E8. SHORT-WINDOW CONFINEMENT ROW
# ================================
e8_data = [
    {"Row": "E8.A", "Structural key": "tetron:3:3:6", "shell signature": "(lambda=3/2, 137, p2, V4)", "B*": 137, "proximity/confinement": "close confined", "transmutation flag": 0},
    {"Row": "E8.B", "Structural key": "tetron:3:3:6", "shell signature": "(lambda=3/2, 139, p3, V4)", "B*": 139, "proximity/confinement": "failed/unconfined", "transmutation flag": 1}
]
df_e8 = pd.DataFrame(e8_data)
print("\n[Example E8] Short-Window Confinement Row:")
display(df_e8)

# E9. DUON / DUAD FAMILY ROW
# ==========================
e9_data = [
    {"Row": "E9.A", "Structural key": "duon:2:1:7", "push/pull": "push", "q_eff": "+1/2", "export witness": "emitted packet", "cadence": "1/3"},
    {"Row": "E9.B", "Structural key": "duad:2:2:7", "push/pull": "balanced", "q_eff": "0", "export witness": "none", "cadence": "1/4"}
]
df_e9 = pd.DataFrame(e9_data)
print("\n[Example E9] Duon / Duad Family Row:")
display(df_e9)

# %% [markdown]
# ### Visual witness: confinement, transmutation, and family bindings
#
# The first panel contrasts close confined vs failed/unconfined short windows. The second panel records the structural keys against their verification bindings.

# %%
# E8/E9 VISUAL: CONFINEMENT / BINDING MAP
fig, ax = plt.subplots(1,2, figsize=(12,4))
# confinement states
states=[1,0]
labels=['close\nconfined','failed\nunconfined']
colors=['tab:green','tab:red']
ax[0].bar(labels, states, color=colors)
ax[0].set_ylim(0,1.2)
ax[0].set_title('Short-window confinement witness')
ax[0].set_ylabel('confined = 1')
# binding map
pairs=[('tetron:1:2:6','electron'),('tetron:3:3:6','proton'),('tetrad:3:4:6','neutron'),('duon/duad','radiation / exchange')]
ax[1].axis('off')
for i,(k,v) in enumerate(pairs):
    y=0.85 - i*0.18
    ax[1].text(0.05,y,k,fontsize=10,ha='left',va='center')
    ax[1].annotate('', xy=(0.62,y), xytext=(0.42,y), arrowprops=dict(arrowstyle='->', lw=1.5))
    ax[1].text(0.66,y,v,fontsize=10,ha='left',va='center')
ax[1].set_title('Structural → verification binding map')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Notebook route note
#
# Optional verification bindings and any temporal-unit conversion rows are attached after the cited row and are routed through `../supplement-b/notebooks/E10-E11D.ipynb`.

# %% [markdown]
# ## Citations & Methodology
#
# **Methodology & Protocol**
# > Reginald, P. (2025). *Axiomatic Fundamentalism (AF): A Logical Protocol for Traceable Research*. Zenodo. https://doi.org/10.5281/zenodo.17561186
#
# **Calculus & Discrete Bookkeeping**
# > Reginald, P. (2025). *Axiomatic Fundamentalism Calculus (AFC): The Hidden Form of Stokes*. Zenodo. https://doi.org/10.5281/zenodo.17807779
#
# **Alpha Omega Dynamics (AOD)**
# > Reginald, P. (2026). *Alpha↔Omega Dynamics: The Hidden Temporal Dynamics of Stokes*. *source note in this repository*

# %%
print("ALL AOD NATIVE TESTS PASSED ✓")
